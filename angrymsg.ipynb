# %%
import numpy as np
from skimage import io
from os import listdir
#import cv2
from cv2 import cvtColor, threshold, morphologyEx, findContours,COLOR_BGRA2BGR,THRESH_BINARY,THRESH_OTSU, RETR_EXTERNAL, MORPH_OPEN, CHAIN_APPROX_SIMPLE, COLOR_BGR2GRAY
from PIL import Image as mg

def polygon_area(points):
    area = 0
    q = points[-1]
    for p in points:
        area += p[0] * q[1] - p[1] * q[0]
        q = p
    return int(abs(area / 2))

input_path="./input"
output_path='./result'
angry=mg.open('angry.png').convert('RGBA')

for filename in listdir(input_path):
    if not (filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg')):
        continue
    fig_path=input_path+'/'+filename
    read=io.imread(fig_path)
    try:
        read=cvtColor(read, COLOR_BGRA2BGR)
    except:
        continue
    h, w, d = read.shape
    gray = cvtColor(read, COLOR_BGR2GRAY)
    ret,thresh = threshold(gray,0,255,THRESH_BINARY+THRESH_OTSU)#二值化
    # 尋找輪廓
    k = np.ones((int(h/100), int(w/100)), np.uint8)  #3x3捲積核
    thresh_open = morphologyEx(thresh, MORPH_OPEN, k)      # 開運算[先膨脹-後腐蝕]
    contours, hierarchy = findContours(thresh_open, RETR_EXTERNAL,CHAIN_APPROX_SIMPLE)


    emoji=[]

    for contour in contours:
        c=np.array(contour)
        if len(c)<3:
            continue
        c=np.squeeze(c)
        ca=(np.max(c[:,0])-np.min(c[:,0]))*(np.max(c[:,1])-np.min(c[:,1]))

        if polygon_area(c)/(h*w)<1/800:
            continue
        if polygon_area(c)/ca<0.85:
            continue
        emoji.append([np.max(c[:,0]), np.max(c[:,1])])
    print(emoji)
    emoji=np.array(emoji)
    
    n=int(w/20)
    angry=angry.resize((n,n))
    r,g,b,a= angry.split()

    result=mg.open(fig_path)
    for p in emoji:
        result.paste(angry, (p[0]-2*n,p[1]-int(n*0.4)),mask=a)
    
    result.save(output_path+'/'+filename, format=None)
# Out:
# [[1145, 1889], [1144, 1592], [1144, 1283]]

# %%
# !Pyinstaller -F -w -i chengzi.ico angrymsg.py

# %%
# !chcp 65001
# !cd C:\Users\goode\Resilio Sync\sync\code\Angry-for-message
# !Pyinstaller -F -w -i chengzi.ico angrymsg.py
# Out:
# Active code page: 65001
# 64 INFO: PyInstaller: 5.6.2
# 64 INFO: Python: 3.10.0
# 71 INFO: Platform: Windows-10-10.0.22621-SP0
# 71 INFO: wrote c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\angrymsg.spec
# 73 INFO: UPX is not available.
# 74 INFO: Extending PYTHONPATH with paths
# ['c:\\Users\\goode\\Resilio Sync\\sync\\code\\Angry-for-message']
# 513 INFO: checking Analysis
# 551 INFO: Building because C:\Users\goode\Resilio Sync\sync\code\Angry-for-message\angrymsg.py changed
# 551 INFO: Initializing module dependency graph...
# 553 INFO: Caching module graph hooks...
# 558 WARNING: Several hooks defined for module 'numpy'. Please take care they do not conflict.
# 559 WARNING: Several hooks defined for module 'numpy'. Please take care they do not conflict.
# 563 INFO: Analyzing base_library.zip ...
# 1528 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 1603 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 2643 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 3485 INFO: Caching module dependency graph...
# 3573 INFO: running Analysis Analysis-00.toc
# 3576 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by C:\Users\goode\AppData\Local\Programs\Python\Python310\python.exe
# 3697 INFO: Analyzing c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\angrymsg.py
# 3734 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 4142 INFO: Loading module hook 'hook-numpy._pytesttester.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 4524 INFO: Loading module hook 'hook-difflib.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 4836 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 5005 INFO: Loading module hook 'hook-xml.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 5599 INFO: Loading module hook 'hook-platform.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 5732 INFO: Loading module hook 'hook-sysconfig.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 6229 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 6956 INFO: Loading module hook 'hook-packaging.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7048 INFO: Loading module hook 'hook-scipy.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7226 INFO: Loading module hook 'hook-scipy.linalg.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7430 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 8170 INFO: Loading module hook 'hook-skimage.io.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 10845 INFO: Loading module hook 'hook-PIL.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 10885 INFO: Loading module hook 'hook-PIL.Image.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 11327 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 11957 INFO: Loading module hook 'hook-matplotlib.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 12274 INFO: Processing pre-safe import module hook gi from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 12762 INFO: Loading module hook 'hook-jinja2.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 13623 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 13937 INFO: Processing pre-safe import module hook six.moves from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 15503 INFO: Loading module hook 'hook-IPython.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 16917 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 17113 INFO: Loading module hook 'hook-pygments.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 18161 INFO: Loading module hook 'hook-pkg_resources.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 19377 INFO: Loading module hook 'hook-lib2to3.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 20164 INFO: Loading module hook 'hook-wcwidth.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 21280 INFO: Loading module hook 'hook-jedi.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 22207 INFO: Loading module hook 'hook-parso.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 23179 INFO: Loading module hook 'hook-sqlite3.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 23878 INFO: Loading module hook 'hook-zmq.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 25305 INFO: Loading module hook 'hook-PyQt5.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 25706 INFO: Loading module hook 'hook-certifi.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 25768 INFO: Loading module hook 'hook-cv2.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 25777 INFO: Processing module hooks...
# 25852 INFO: Loading module hook 'hook-imageio.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 26738 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 26739 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 26761 INFO: Selected matplotlib backends: ['TkAgg']
# 26907 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 26962 INFO: Processing pre-safe import module hook win32com from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 27037 INFO: Loading module hook 'hook-win32com.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27038 INFO: Loading module hook 'hook-pythoncom.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27274 INFO: Loading module hook 'hook-pywintypes.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27645 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 27680 INFO: Loading module hook 'hook-distutils.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 27687 INFO: Loading module hook 'hook-distutils.util.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 28762 INFO: Loading module hook 'hook-PyQt5.QtCore.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 28868 INFO: Loading module hook 'hook-PyQt5.QtGui.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 29015 INFO: Loading module hook 'hook-PyQt5.QtWidgets.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 29177 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 30169 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 31079 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 31079 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 31081 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 31165 INFO: checking Tree
# 31191 INFO: checking Tree
# 31242 INFO: checking Tree
# 32028 INFO: Looking for ctypes DLLs
# 32072 INFO: Analyzing run-time hooks ...
# 32081 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 32082 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_subprocess.py'
# 32082 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 32084 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 32085 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 32086 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 32087 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 32089 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 32090 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 32090 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 32091 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pyqt5.py'
# 32092 INFO: Including run-time hook 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 32115 INFO: Looking for dynamic libraries
# C:\Users\goode\AppData\Local\Programs\Python\Python310\lib\site-packages\PyInstaller\building\build_main.py:173: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# C:\Users\goode\AppData\Local\Programs\Python\Python310\lib\site-packages\PyInstaller\isolated\_child.py:94: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 1255 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\numpy\\.libs', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\../../x64/vc14/bin', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\scipy\\.libs', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\pyzmq.libs', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyQt5\\Qt5\\bin']
# 1255 INFO: Extra DLL search directories (PATH): ['C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyQt5\\Qt5\\bin', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\../../x64/vc14/bin', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\../../x64/vc14/bin', 'c:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310', 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.8\\bin', 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.8\\libnvvp', 'C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath', 'C:\\Windows\\system32', 'C:\\Windows', 'C:\\Windows\\System32\\Wbem', 'C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\Windows\\System32\\OpenSSH\\', 'C:\\Program Files\\dotnet\\', 'C:\\Program Files\\MiKTeX\\miktex\\bin\\x64\\', 'C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common', 'C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR', 'C:\\Program Files (x86)\\ZeroTier\\One\\', 'C:\\TDM-GCC-64\\bin', 'C:\\Program Files\\Git\\cmd', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\Scripts', 'C:\\WINDOWS\\system32', 'C:\\WINDOWS', 'C:\\WINDOWS\\System32\\Wbem', 'C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\WINDOWS\\System32\\OpenSSH\\', 'C:\\Program Files\\Calibre2\\', 'C:\\Program Files\\NVIDIA Corporation\\Nsight Compute 2022.3.0\\', 'C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\', 'C:\\Users\\goode\\AppData\\Local\\activestate\\cache\\bin', 'C:\\Users\\goode\\AppData\\Local\\ActiveState\\StateTool\\release\\bin', 'C:\\Users\\goode\\AppData\\Local\\Microsoft\\WindowsApps', 'C:\\Users\\goode\\AppData\\Local\\Programs\\Microsoft VS Code\\bin', 'C:\\Users\\goode\\AppData\\Local\\GitHubDesktop\\bin', 'C:\\Program Files (x86)\\Prince\\engine\\bin', 'C:\\Users\\goode\\AppData\\Local\\Pandoc\\', 'C:\\Program Files\\pdf2svg-windows-master\\dist-64bits', 'C:\\Program Files\\upgit\\upgit.exe', 'C:\\Users\\goode\\OneDrive\\文件\\zlib\\dll_x64\\zlibwapi.dll']
# 34900 INFO: Looking for eggs
# 34900 INFO: Using Python library C:\Users\goode\AppData\Local\Programs\Python\Python310\python310.dll
# 34900 INFO: Found binding redirects:
# []
# 34913 INFO: Warnings written to c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\build\angrymsg\warn-angrymsg.txt
# 35079 INFO: Graph cross-reference written to c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\build\angrymsg\xref-angrymsg.html
# 35175 INFO: checking PYZ
# 35187 INFO: Building because toc changed
# 35187 INFO: Building PYZ (ZlibArchive) c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\build\angrymsg\PYZ-00.pyz
# 36880 INFO: Building PYZ (ZlibArchive) c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\build\angrymsg\PYZ-00.pyz completed successfully.
# 36917 INFO: checking PKG
# 36940 INFO: Building because toc changed
# 36940 INFO: Building PKG (CArchive) angrymsg.pkg
# 37702 WARNING: One binary added with two internal names.
# 37702 WARNING: ('pyzmq.libs\\libsodium-138090d4.dll',
#  'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\pyzmq.libs\\libsodium-138090d4.dll',
#  'BINARY')
# 37702 WARNING: was placed previously at
# 37702 WARNING: ('libsodium-138090d4.dll',
#  'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\pyzmq.libs\\libsodium-138090d4.dll',
#  'BINARY')
# 37707 WARNING: One binary added with two internal names.
# 37707 WARNING: ('scipy\\.libs\\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll',
#  'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\scipy\\.libs\\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll',
#  'BINARY')
# 37707 WARNING: was placed previously at
# 37707 WARNING: ('libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll',
#  'C:\\Users\\goode\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\scipy\\.libs\\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll',
#  'BINARY')
# 67103 INFO: Building PKG (CArchive) angrymsg.pkg completed successfully.
# 67163 INFO: Bootloader C:\Users\goode\AppData\Local\Programs\Python\Python310\lib\site-packages\PyInstaller\bootloader\Windows-64bit\runw.exe
# 67164 INFO: checking EXE
# 67185 INFO: Building because toc changed
# 67185 INFO: Building EXE from EXE-00.toc
# 67193 INFO: Copying bootloader EXE to c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\dist\angrymsg.exe.notanexecutable
# 67198 INFO: Copying icon to EXE
# 67198 INFO: Copying icons from ['c:\\Users\\goode\\Resilio Sync\\sync\\code\\Angry-for-message\\chengzi.ico']
# 67242 INFO: Writing RT_GROUP_ICON 0 resource with 20 bytes
# 67242 INFO: Writing RT_ICON 1 resource with 4264 bytes
# 67244 INFO: Copying 0 resources to EXE
# 67244 INFO: Embedding manifest in EXE
# 67245 INFO: Updating manifest in c:\Users\goode\Resilio Sync\sync\code\Angry-for-message\dist\angrymsg.exe.notanexecutable
# 67285 INFO: Updating resource type 24 name 1 language 0
# 67287 INFO: Appending PKG archive to EXE
# 67389 INFO: Fixing EXE headers
# 73109 INFO: Building EXE from EXE-00.toc completed successfully.
